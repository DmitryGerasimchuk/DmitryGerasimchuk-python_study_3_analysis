# %%
import pandas as pd

# %%
import numpy as np

# %%
a = pd.Series([4, 6, 7, 5, 9],
          index=['one', 'two', 'three', 'four', 'five'])

a
# Out:
# one      4
# two      6
# three    7
# four     5
# five     9
# dtype: int64

# %%
b = pd.Series([2, 4, 6, 8, 9])

b
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# 4    9
# dtype: int64

# %%
a.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
b.values
# Out:
# array([2, 4, 6, 8, 9], dtype=int64)

# %%
a['one']
# Out:
# 4

# %%
b[4]
# Out:
# 9

# %%
df = pd.DataFrame({
    'Age': [46, 47, 38, 65, 41],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male'],
    'Name': ['Ann', 'Kate', 'Karl', 'Mike', 'Denis']},
    index=['one', 'two', 'three', 'four', 'five']
)

df
# Out:
#        Age  Country  Gender   Name
# one     46    Spain  Female    Ann
# two     47    Spain  Female   Kate
# three   38  Germany    Male   Karl
# four    65  Germany    Male   Mike
# five    41   France    Male  Denis

# %%
df['Name']
# Out:
# one        Ann
# two       Kate
# three     Karl
# four      Mike
# five     Denis
# Name: Name, dtype: object

# %%
df.Name
# Out:
# one        Ann
# two       Kate
# three     Karl
# four      Mike
# five     Denis
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#         Name  Age
# one      Ann   46
# two     Kate   47
# three   Karl   38
# four    Mike   65
# five   Denis   41

# %%
df.columns
# Out:
# Index(['Age', 'Country', 'Gender', 'Name'], dtype='object')

# %%
df.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
df.index = [0, 1, 2, 3, 4]

df
# Out:
#    Age  Country  Gender   Name
# 0   46    Spain  Female    Ann
# 1   47    Spain  Female   Kate
# 2   38  Germany    Male   Karl
# 3   65  Germany    Male   Mike
# 4   41   France    Male  Denis

# %%
df = pd.read_csv('Churn_Modelling.csv')

df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = pd.read_csv('Churn_Modelling.csv', header=0, sep=',')

df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.tail(2)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.sample(2)
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 3821       3822    15685245  Jowett          608     Spain  Female   56
# 6282       6283    15761340  Bullen          521    France    Male   22
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 3821       5      0.0              2          0               1
# 6282       5      0.0              2          1               1
#
#       EstimatedSalary  Exited
# 3821        153810.41       0
# 6282         99828.45       0

# %%
df.sample(frac=1)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 7415       7416    15635598      Hsieh          812    France    Male   29
# 5438       5439    15633274        Tai          679    France    Male   34
# 377         378    15667871       Kerr          572     Spain    Male   35
# 8763       8764    15665159     Brooks          727    France    Male   61
# 7359       7360    15731989      Moran          666    France    Male   36
# ...         ...         ...        ...          ...       ...     ...  ...
# 9886       9887    15719541  Flannagan          675     Spain    Male   31
# 1744       1745    15682533     Hughes          850    France  Female   39
# 846         847    15608968  Averyanov          714   Germany    Male   21
# 3651       3652    15628999   Townsend          732    France    Male   79
# 2394       2395    15716284       Ward          543    France    Male   43
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(frac=0.25)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 4664       4665    15580719        Davis          697    France  Female   23
# 5028       5029    15761168        Manna          478    France  Female   38
# 3888       3889    15576094         Sung          743    France    Male   71
# 1344       1345    15691104      Kennedy          460   Germany  Female   40
# 1398       1399    15628947        Praed          693    France  Female   38
# ...         ...         ...          ...          ...       ...     ...  ...
# 1703       1704    15750466       Rhodes          790   Germany    Male   42
# 928         929    15677135      Lorenzo          520   Germany    Male   61
# 8394       8395    15597983        Brown          692    France    Male   69
# 4871       4872    15575858  Bergamaschi          763    France    Male   40
# 2961       2962    15583681         Layh          616     Spain    Male   31
#
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 976.6+ KB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Balance'].max()
# Out:
# 250898.09

# %%
df[['Age', 'Tenure', 'Balance']].min()
# Out:
# Age        18.0
# Tenure      0.0
# Balance     0.0
# dtype: float64

# %%
df.describe(include=['object'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'].astype('bool')
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'] = df['HasCrCard'].astype('bool')

# %%
df['HasCrCard'].dtype
# Out:
# dtype('bool')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64, 18, 82, 69, 74, 71, 76, 77, 88, 85, 84, 78, 81,
#        92, 83], dtype=int64)

# %%
df['Surname'].unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %%
df['Surname'].nunique()
# Out:
# 2932

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Surname'].value_counts()
# Out:
# Surname
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: count, Length: 2932, dtype: int64

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 37    0.0478
# 38    0.0477
# 35    0.0474
# 36    0.0456
# 34    0.0447
#        ...
# 92    0.0002
# 82    0.0001
# 88    0.0001
# 85    0.0001
# 83    0.0001
# Name: proportion, Length: 70, dtype: float64

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
man = df[df['Gender'] == 'Male']

man
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
man_18 = df[(df['Gender'] == 'Male') & (df['Age'] == 37)]

man_18
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 147         148    15754105  Olisanugo          650    France   Male   37
# 153         154    15689044  Humphries          539    France   Male   37
# 197         198    15777892  Samsonova          721   Germany   Male   37
# 205         206    15773039         Ku          550    France   Male   37
# 225         226    15699029     Bagley          670    France   Male   37
# ...         ...         ...        ...          ...       ...    ...  ...
# 9853       9854    15576615   Giordano          719     Spain   Male   37
# 9872       9873    15648032      Young          588     Spain   Male   37
# 9890       9891    15670427      Chidi          662     Spain   Male   37
# 9952       9953    15696355  Cleveland          724   Germany   Male   37
# 9958       9959    15657771      Ts'ui          537    France   Male   37
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
man_18_woman_18 = df[((df['Gender'] == 'Male') & (df['Age'] == 18)) | ((df['Gender'] == 'Female') & (df['Age'] == 18))]

man_18_woman_18
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 746         747    15787619            Hsieh          844    France    Male
# 1619       1620    15770309         McDonald          656    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 2021       2022    15795519         Vasiliev          716   Germany  Female
# 2136       2137    15621893         Bellucci          727    France    Male
# 2141       2142    15758372          Wallace          674    France    Male
# 3330       3331    15657439             Chao          738    France    Male
# 3512       3513    15657779           Boylan          806     Spain    Male
# 3517       3518    15757821          Burgess          771     Spain    Male
# 3686       3687    15665327         Cattaneo          706    France    Male
# 4556       4557    15796231          Nwankwo          681    France  Female
# ...

# %%
not_France = df[~(df['Geography'] == 'France')]

not_France
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 1             2    15647311         Hill          608     Spain  Female   41
# 4             5    15737888     Mitchell          850     Spain  Female   43
# 5             6    15574012          Chu          645     Spain    Male   44
# 7             8    15656148       Obinna          376   Germany  Female   29
# 11           12    15737173      Andrews          497     Spain    Male   24
# ...         ...         ...          ...          ...       ...     ...  ...
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %%
not_France = df[df['Geography'].isin(['Spain', 'Germany'])]

not_France
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 1             2    15647311         Hill          608     Spain  Female   41
# 4             5    15737888     Mitchell          850     Spain  Female   43
# 5             6    15574012          Chu          645     Spain    Male   44
# 7             8    15656148       Obinna          376   Germany  Female   29
# 11           12    15737173      Andrews          497     Spain    Male   24
# ...         ...         ...          ...          ...       ...     ...  ...
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %%
df_small = df[(df['Geography'] == 'Spain')][['Geography', 'Gender', 'Age']]

df_small.head(3)
# Out:
#   Geography  Gender  Age
# 1     Spain  Female   41
# 4     Spain  Female   43
# 5     Spain    Male   44

# %%
df_small.loc[4]
# Out:
# Geography     Spain
# Gender       Female
# Age              43
# Name: 4, dtype: object

# %%
df_small.loc[[1, 5],['Age']]
# Out:
#    Age
# 1   41
# 5   44

# %%
df_small.head(9)
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35
# 17     Spain  Female   24
# 18     Spain    Male   45
# 21     Spain  Female   32
# 22     Spain  Female   38

# %%
df_small.iloc[[0, 1, 2, 3, 4]]
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %%
df_small.iloc[0, [1, 2]]
# Out:
# Gender    Female
# Age           41
# Name: 1, dtype: object

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
# ...

# %%
df.sort_values(['Age', 'Surname'], ascending=False)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 6759       6760    15660878     T'ien          705    France    Male   92
# 6443       6444    15764927    Rogova          753    France    Male   92
# 2458       2459    15813303   Rearick          513     Spain    Male   88
# 3033       3034    15578006       Yao          787    France  Female   85
# 3387       3388    15798024      Lori          537   Germany    Male   84
# ...         ...         ...       ...          ...       ...     ...  ...
# 3686       3687    15665327  Cattaneo          706    France    Male   18
# 3517       3518    15757821   Burgess          771     Spain    Male   18
# 9029       9030    15722701     Bruno          594   Germany    Male   18
# 3512       3513    15657779    Boylan          806     Spain    Male   18
# 2136       2137    15621893  Bellucci          727    France    Male   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
